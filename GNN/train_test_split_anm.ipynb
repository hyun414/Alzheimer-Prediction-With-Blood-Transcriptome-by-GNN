# %%
import pandas as pd
import numpy as np
import csv
from sklearn.model_selection import train_test_split

total_data = pd.read_csv('/work/home/nhkim/BiS495/data_f/f_data.csv')
total_label = pd.read_csv('/work/home/nhkim/BiS495/data_f/f_label.csv')

# %%
labels = total_label.iloc[:, 1]

# %%
features_labels = pd.concat([total_data, labels], axis=1)
df = features_labels

# %%
gsm_df = df[df['Unnamed: 0'].str.startswith('GSM')]

# %%
features = gsm_df.iloc[:, 1:]
print(features.head)
# Out:
# <bound method NDFrame.head of             0         1         2         3         4         5         6  \
# 199  8.247675  5.965321  6.506070  8.271208  6.292572  5.934994  7.555875
# 200  7.676184  5.987453  6.898373  8.347713  6.498518  6.113024  7.776880
# 201  8.526712  6.397461  6.492418  8.384282  6.222537  6.045201  7.398379
# 202  8.105511  6.000882  6.689543  8.389288  6.370782  6.133207  7.358406
# 203  7.917722  5.902909  6.595167  8.372026  6.226665  6.129843  7.379138
# ..        ...       ...       ...       ...       ...       ...       ...
# 716  8.717987  5.853000  6.345874  8.156612  6.995375  6.248531  7.202095
# 717  8.275518  5.721968  6.453518  8.321518  6.693715  5.946753  7.554490
# 718  8.258927  6.621491  6.708368  7.935200  6.362053  6.277836  7.403825
# 719  7.936922  6.391150  6.478339  8.029154  6.474632  6.139475  7.023998
# 720  8.403735  6.032685  6.475049  8.374373  6.442738  6.015959  7.145670
#
# ...

# %%
deg = pd.read_csv('/work/home/nhkim/BiS495/data_f/degs_results5.csv')
degs = deg.iloc[:, 0]
print(degs.head())
# Out:
# 0    6761
# 1    4390
# 2    4772
# 3     438
# 4    6806
# Name: Unnamed: 0, dtype: int64

# %%
columns_to_keep = degs.values
features_filtered = features.iloc[:, columns_to_keep]

print(features_filtered)
# Out:
#           6761       4390      4772       438       6806      4415      4902  \
# 199  11.058867  10.767136  9.544803  8.492793  12.353493  9.138860  9.416464
# 200  11.167884  10.837795  9.507561  8.664460  12.678068  9.150847  9.311175
# 201  11.165579  10.778143  9.691676  8.715290  12.667157  9.129223  9.638339
# 202  11.013462  10.775467  9.556476  8.452542  12.510586  8.749233  9.109187
# 203  11.170621  10.822999  9.573381  8.566622  12.552491  8.957859  9.442718
# ..         ...        ...       ...       ...        ...       ...       ...
# 716   9.748037   9.005072  8.888834  7.814813  11.398599  7.331970  8.814332
# 717  11.061728  10.329492  9.290577  8.062422  12.385567  8.406154  9.292417
# 718   9.871964   9.429399  8.395488  7.979052  11.386772  7.334116  8.606031
# 719  10.533702   9.876131  8.894271  8.127636  12.066756  7.808747  8.991619
# 720  10.121155   9.670561  8.735893  8.200683  12.094331  8.269962  9.142348
#
# ...

# %%
X = features_filtered

# %%
y = labels[199:]

# %%
print(y)
# Out:
# 199    0
# 200    0
# 201    0
# 202    0
# 203    0
#       ..
# 716    1
# 717    1
# 718    1
# 719    0
# 720    0
# Name: diagnosis, Length: 522, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
X_train.to_csv('/work/home/nhkim/BiS495/GNN/input_features_labels/split10_train_features.csv')
X_test.to_csv('/work/home/nhkim/BiS495/GNN/input_features_labels/split10_test_features.csv')

y_train.to_csv('/work/home/nhkim/BiS495/GNN/input_features_labels/split10_train_labels.csv')
y_test.to_csv('/work/home/nhkim/BiS495/GNN/input_features_labels/split10_test_labels.csv')
